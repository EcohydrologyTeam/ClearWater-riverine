# %% [markdown]
# # Refactor: Clearwater-Data
#
# ## Imports

# %%
import sys

# %%
sys.path.append(r"C:\Users\sjordan\OneDrive - LimnoTech\Documents\GitHub\ClearWater-data")

# %%
import clearwater_data

# %%
import clearwater_riverine as cwr
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## Read from config

# %%
network_path = Path('../data_temp/sumwere_creek_coarse_p48')
config_file = network_path / 'demo_config.yml'

# %%
# %%time
transport_model = cwr.ClearwaterRiverine(
    config_filepath=config_file,
    verbose=True,
    start_datetime=pd.to_datetime('2022-05-13 08:00:00'),
    end_datetime=pd.to_datetime('2022-05-13 10:00:00'),
)
# Out:
# Populating Model Mesh...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:163, in ClearwaterRiverine.__init__(self, flow_field_file_path, diffusion_coefficient_input, constituent_dict, config_filepath, verbose, start_datetime, end_datetime, variable_registry, mesh_file_path)
#     157 else:
#     158     # Read HEC RAS HDF
#     159     ## In the future, if we adapt to additional models, make this configurable
#     160     ## For now, there is only one option so we can call the data souce directly
#     161     ## TODO: move to config scripts, mirroring modules
#     162     if verbose: print("Populating Model Mesh...")  ## TODO: Add to logging
# --> 163     self.__data_sources['hydrodynamic_model'] = RASHDFDataSource(
#     164         ras_hdf_path=flow_field_file_path,
#     165         start_datetime=self.__start_datetime,
#     166         end_datetime=self.__end_datetime,
#     167     )
#     168     ## TODO: add chunking
#     169     for variable_name in self.__data_sources['hydrodynamic_model'].temporal_variables:
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\hdf.py:124, in RASHDFDataSource.__init__(self, **kwargs)
#     114 self.static_variables = {
#     115     FACE_SURFACE_AREA: 'nface',
#     116     EDGE_LENGTH: 'nedge',
#     117     VOLUME_ELEVATION_INFO: None,
#     118     VOLUME_ELEVATION_VALUES: None,
#     119 }
#     121 ## TODO: add datetime validation somewhere
#     122 # self.__validate_datetime_range()
# --> 124 with h5py.File(self.file_path, 'r') as infile:
#     125     # set-up steps
#     126     self.project_name = infile[
#     127         'Geometry/2D Flow Areas/Attributes'
#     128     ][()][0][0].decode('UTF-8')
#     129     self.paths = self.__set_internal_paths()
#
# AttributeError: 'RASHDFDataSource' object has no attribute 'file_path'
