# %% [markdown]
# # Refactor: Clearwater-Data
#
# ## Imports

# %%
import sys

# %%
sys.path.append(r"C:\Users\sjordan\OneDrive - LimnoTech\Documents\GitHub\ClearWater-data")

# %%
import clearwater_data

# %%
import clearwater_riverine as cwr
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## Read from config

# %%
network_path = Path('../data_temp/sumwere_creek_coarse_p48')
config_file = network_path / 'demo_config.yml'

# %%
# %%time
transport_model = cwr.ClearwaterRiverine(
    config_filepath=config_file,
    verbose=True,
    start_datetime=pd.to_datetime('2022-05-13 08:00:00'),
    end_datetime=pd.to_datetime('2022-05-13 10:00:00'),
)
# Out:
# Populating Model Mesh...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Anaconda3\envs\clearwater_riverine\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:170, in ClearwaterRiverine.__init__(self, flow_field_file_path, diffusion_coefficient_input, constituent_dict, config_filepath, verbose, start_datetime, end_datetime, variable_registry, mesh_file_path)
#     168 ## TODO: add chunking
#     169 for variable_name in self.__data_sources['hydrodynamic_model'].temporal_variables:
# --> 170     self.__data_sources['hydrodynamic_model'].read(variable_name)
#     171     self.__registry.register(
#     172         variable_name,
#     173         self.__data_sources['hydrodynamic_model'].mesh[variable_name]
#     174     )
#     175 for variable_name in self.__data_sources['hydrodynamic_model'].static_variables:
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\hdf.py:289, in RASHDFDataSource.read(self, parameter_name)
#     288 def read(self, parameter_name:str) -> DataArrayVariable:
# --> 289     return DataArrayVariable(self.__read(parameter_name))
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\hdf.py:295, in RASHDFDataSource.__read(self, parameter_name)
#     293     return self.mesh[parameter_name]
#     294 else:
# --> 295     self.__subset_datetimes(
#     296         self.start_datetime,
#     297         self.end_datetime,
#     298     )
#     299     self.__update_time_coordinate()
#     300     self.__update_mesh()
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\hdf.py:347, in RASHDFDataSource.__subset_datetimes(self, start_datetime, end_datetime)
#     340 def __subset_datetimes(
#     341     self,
#     342     start_datetime: datetime,
#     343     end_datetime: datetime,
#     344 ):
#     346     subset_dates = self.all_datetimes[
# --> 347         (self.all_datetimes[0] >= start_datetime) & (self.all_datetimes[-1] <= end_datetime)
#     348     ]
#     349     subset_indices = subset_dates.index.intersection(
#     350         self.all_datetimes.index
#     351     )
#     352     self.datetime_range_indices: Tuple[int, int] = (
#     353         subset_indices[0],
#     354         subset_indices[-1] + 1
#     355     )
#
# File ~\Anaconda3\envs\clearwater_riverine\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~\Anaconda3\envs\clearwater_riverine\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~\Anaconda3\envs\clearwater_riverine\Lib\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: -1
