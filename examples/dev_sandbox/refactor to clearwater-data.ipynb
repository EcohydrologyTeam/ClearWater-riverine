# %% [markdown]
# # Refactor: Clearwater-Data
#
# ## Imports

# %%
import sys

# %%
sys.path.append(r"C:\Users\sjordan\OneDrive - LimnoTech\Documents\GitHub\ClearWater-data")

# %%
import clearwater_data

# %%
import clearwater_riverine as cwr
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## Read from config

# %%
network_path = Path('../data_temp/sumwere_creek_coarse_p48')
config_file = network_path / 'example_config_refactor.yml'

# %%
# %%time
transport_model = cwr.ClearwaterRiverine(
    config_filepath=config_file,
    # verbose=True,
    # start_datetime=pd.to_datetime('2022-05-13 08:00:00'),
    # end_datetime=pd.to_datetime('2022-05-13 10:00:00'),
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:117, in ClearwaterRiverine.__init__(self, config_filepath, flow_field_file_path, constituent_dict, start_datetime, end_datetime, variable_registry, chunk_size)
#     114 self.registry = variable_registry if variable_registry is not None else VariableRegistry()
#     116 if config_filepath:
# --> 117     model, data_sources, constituents = init_from_config(config_filepath)
#     118     self.__flow_field_file_path = model.get("file_path", None)
#     119     self.__chunk_size = model.get("chunk_size", None)
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\config.py:30, in init_from_config(config_filepath)
#      27 model = config['model']
#      28 constituents = list(config['constituents'].keys())
# ---> 30 data_sources = __init_data_sources(config)
#      32 return model, constituents, data_sources
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\config.py:59, in __init_data_sources(config)
#      57 # Initialize all data souces (like )
#      58 for source_name, source_config in config["data_sources"].items():
# ---> 59     data_source[source_name]  = __init_single_data_source(source_name, source_config)
#      61 # Initialize all constituent data sources
#      62 for source_name, source_config in config["constituents"].items():
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\io\config.py:46, in __init_single_data_source(source_name, source_config)
#      44     return CSVDataSource(**source_config["data"])
#      45 elif provider_name == "float":
# ---> 46     return FloatDataSource(**source_config["data"])
#      47 else:
#      48     raise ValueError(
#      49         f"Unknown or unsupported provider `{provider_name}` for data_source `{source_name}`"
#      50     )
#
# KeyError: 'data'
