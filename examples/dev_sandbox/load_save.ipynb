# %%
from pathlib import Path
import clearwater_riverine as cwr
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1005'>
#   <div id="cbca367e-763a-41bc-9d21-33b0cd31c9fb" data-root-id="p1005" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"81acfb06-f097-4951-9386-f67249c4cd78":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1005"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1006","attributes":{"plot_id":"p1005","comm_id":"ce3a72ef7b374fecafcf8f1ead84d43e","client_comm_id":"687aef0c7c0e4f64813c47621fb8236c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"81acfb06-f097-4951-9386-f67249c4cd78","roots":{"p1005":"cbca367e-763a-41bc-9d21-33b0cd31c9fb"},"root_ids":["p1005"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
dir = Path.cwd()

# %%
network_path =  dir / 'temp/sumwere_creek_coarse_p48'
config_file = network_path / 'demo_config.yml'

# %%
config_file
# Out:
# WindowsPath('c:/Users/sjordan/OneDrive - LimnoTech/Documents/GitHub/ClearWater-riverine/examples/dev_sandbox/temp/sumwere_creek_coarse_p48/demo_config.yml')

# %%
# test on 100 timesteps
start_index =  0 # int((8*60*60)/30)
end_index = 100

# %%
# %%time
transport_model = cwr.ClearwaterRiverine(
    config_filepath=config_file,
    verbose=True,
    datetime_range= (start_index, end_index)
)
# Out:
# Populating Model Mesh...
# Calculating Required Parameters...
# CPU times: total: 672 ms
# Wall time: 879 ms

# %%
for _ in range(len(transport_model.mesh.time) - 1):
    transport_model.update()

# %%
transport_model.finalize(
    save=True,
    output_filepath='./temp/sumwere_creek_coarse_p48/output.nc'
)

# %%
transport_model = cwr.ClearwaterRiverine(
    mesh_file_path='./temp/sumwere_creek_coarse_p48/output.nc'
)

# %%
transport_model.plot(
    crs='EPSG:26916',
)
# Out:
# C:\Users\sjordan\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:549: UserWarning: No constituent name defined. Plotting temperature.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 transport_model.plot(
#       2     crs='EPSG:26916',
#       3 )
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:622, in ClearwaterRiverine.plot(self, constituent_name, crs, clim, cmap, time_index_range, filter_empty)
#     599 def plot(
#     600     self,
#     601     constituent_name: Optional[str] = None,
#    (...)
#     606     filter_empty: Optional[bool] = True,
#     607 ):
#     608     """Creates a dynamic polygon plot of concentrations in the RAS2D model domain.
#     609
#     610     The `plot()` method takes slightly  more time than the `quick_plot()` method in order to leverage the `geoviews` plotting library.
#    (...)
#     619         filter_empty (boolean, optional): provides users the ability to filter out empty cells.
#     620     """
# --> 622     constituent_name, mx_val, mn_val = self._prep_plot(
#     623         constituent_name=constituent_name,
#     624         clim=clim,
#     625         gdf_plot=True,
#     626         crs=crs,
#     627     )
#     629     def map_generator(datetime):
#     630         """This function generates plots for the DynamicMap"""
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:592, in ClearwaterRiverine._prep_plot(self, constituent_name, clim, gdf_plot, crs)
#     588         self._update_gdf()
#     590 constituent_name = self._check_constituent(constituent_name)
# --> 592 mx_val, mn_val = self._define_clims(
#     593     clim=clim,
#     594     constituent_name=constituent_name
#     595 )
#     596 return constituent_name, mx_val, mn_val
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:562, in ClearwaterRiverine._define_clims(self, clim, constituent_name)
#     555 def _define_clims(
#     556     self,
#     557     clim: tuple,
#     558     constituent_name: str,
#     559 ):
#     560     """Define color limit extent."""
# --> 562     mx_val = self._maximum_plotting_value(
#     563         clim_max=clim[1],
#     564         constituent_name=constituent_name
#     565     )
#     566     mn_val = self._minimum_plotting_value(
#     567         clim_min=clim[0],
#     568         constituent_name=constituent_name
#     569     )
#     570     return mx_val, mn_val
#
# File ~\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\src\clearwater_riverine\transport.py:512, in ClearwaterRiverine._maximum_plotting_value(self, clim_max, constituent_name)
#     510     mx_val = clim_max
#     511 else:
# --> 512     if self.constituent_dict[constituent_name].max_value == None:
#     513         self.set_value_range(constituent_name)
#     514     mx_val = self.constituent_dict[constituent_name].max_value
#
# AttributeError: 'ClearwaterRiverine' object has no attribute 'constituent_dict'

# %%
transport_model.mesh
# Out:
# <xarray.Dataset>
# Dimensions:                 (node: 549, time: 101, nface: 444, nmax_face: 8,
#                              nedge: 915, 2: 2)
# Coordinates:
#     node_x                  (node) float64 ...
#     node_y                  (node) float64 ...
#   * time                    (time) datetime64[ns] 2022-05-13 ... 2022-05-13T0...
#     face_x                  (nface) float64 ...
#     face_y                  (nface) float64 ...
# Dimensions without coordinates: node, nface, nmax_face, nedge, 2
# Data variables: (12/18)
#     mesh2d                  int32 ...
#     face_nodes              (nface, nmax_face) int32 0 1 2 3 545 ... -1 -1 -1 -1
#     edge_nodes              (nedge, 2) int32 ...
#     edge_face_connectivity  (nedge, 2) int32 ...
#     edges_face1             (nedge) int32 ...
#     edges_face2             (nedge) int32 ...
#     ...                      ...
#     advection_coeff         (time, nedge) float32 ...
#     edge_vertical_area      (time, nedge) float32 ...
#     face_to_face_dist       (nedge) float64 ...
#     coeff_to_diffusion      (time, nedge) float64 ...
#     dt                      (time) float64 ...
#     temperature             (time, nface) float64 ...
# Attributes:
#     Conventions:            CF-1.8 UGRID-1.0 Deltares-0.10
#     diffusion_coefficient:  0.1
#     units:                  Metric
#     nreal:                  366

# %%
from clearwater_riverine.variables import (
    HYDRODYNAMIC_VARIABLES,
    TOPOLOGY_VARIABLES
)

# %%
[f for f in transport_model.mesh.data_vars
 if 'nface' in transport_model.mesh[f].dims and f not in HYDRODYNAMIC_VARIABLES and 
 f not in TOPOLOGY_VARIABLES]
# Out:
# ['temperature']
