# %%
import numba
import numpy as np
import pandas as pd
import holoviews as hv

import clearwater_riverine as cwr
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1005'>
#   <div id="ad8b8865-d4cf-404b-883a-e61408804eb5" data-root-id="p1005" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
root = r'.\data\sumwere_test_cases\plan27_crsMsh'
ras_filepath = f'{root}/clearWaterTestCases.p27.hdf'
initial_condition_path = f'{root}/cwr_initial_conditions_waterTemp_p28.csv'
boundary_condition_path = f'{root}/cwr_boundary_conditions_waterTemp_p28.csv'

# %%
# %%time
transport_model = cwr.ClearwaterRiverine(ras_filepath, 0.001, verbose=True)
# Out:
# Populating Model Mesh...
# Calculating Required Parameters...
#  Calculating sum coefficient to diffusion term...
# CPU times: total: 5.5 s
# Wall time: 5.53 s

# %%
pd.read_csv(boundary_condition_path)
# Out:
#   RAS2D_TS_Name        Datetime  Concentration
# 0       US_Flow  5/12/2022 0:00             20
# 1       US_Flow  5/17/2022 0:00             20
# 2      DS_Stage  5/12/2022 0:00             20
# 3      DS_Stage  5/17/2022 0:00             20
# 4  PwrPlnt_Flow  5/12/2022 0:00             25
# 5  PwrPlnt_Flow  5/17/2022 0:00             25

# %%
transport_model.initial_conditions(initial_condition_path)

# %%
# %%time
transport_model.boundary_conditions(boundary_condition_path)
# Out:
# CPU times: total: 62.5 ms
# Wall time: 59.7 ms

# %%
# %%time
transport_model.simulate_wq(save=False,
                  input_mass_units = 'mg',
                  input_volume_units = 'm3',
                  input_liter_conversion = 1000)
# Out:
# Starting WQ Simulation...
#  Assuming concentration input has units of mg/m3...
#      If this is not true, please re-run the wq simulation with input_mass_units, input_volume_units, and liter_conversion parameters filled in appropriately.
#  25%
#  50%
#  75%
#  100%
# CPU times: total: 2min 8s
# Wall time: 2min 10s

# %%
transport_model.plot(crs='EPSG:26916')
# Out:
# :DynamicMap   [datetime]
#    :Overlay
#       .Polygons.I :Polygons   [Longitude,Latitude]   (concentration,cell)
#       .WMTS.I     :WMTS   [Longitude,Latitude]
