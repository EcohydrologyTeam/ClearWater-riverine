# %% [markdown]
# This notebook tests the functions for the initial pytest case

# %%
from clearwater_riverine.postproc_util import _run_simulation
from clearwater_riverine.postproc_util import _mass_bal_global
from clearwater_riverine.postproc_util import _mass_bal_global_100_Ans
from clearwater_riverine.postproc_util import _mass_bal_val
from pathlib import Path
import os

#find path to simulation files
sandbox_dir_str = os.path.abspath("")
sandbox_dir = Path(sandbox_dir_str)
cwr_dir = Path(sandbox_dir).parent.parent
smpl_test_dir = cwr_dir / "tests" / "data" / "sumwere_test_cases"

#define inputs for simulation and run simulation
fpath = smpl_test_dir / "plan11_stormSurge" / "clearWaterTestCases.p11.hdf"
diff_coef = 0.01
intl_cond = smpl_test_dir / "plan11_stormSurge" / "cwr_initial_conditions_p11.csv"
bndry_cond = smpl_test_dir / "plan11_stormSurge" / "cwr_boundary_conditions_p11.csv"
plan11 = _run_simulation(fpath, diff_coef, intl_cond, bndry_cond)

#test mass balance functions
massBal_df = _mass_bal_global(plan11)
massBal_df_100 = _mass_bal_global_100_Ans(plan11)
mass = _mass_bal_val(massBal_df, 'Mass_end')

print(massBal_df)
print(massBal_df_100)
print(mass)
# Out:
# C:\Users\jrutyna\.conda\envs\clearwater_riverine\lib\site-packages\geoviews\operation\__init__.py:14: HoloviewsDeprecationWarning: 'ResamplingOperation' is deprecated and will be removed in version 1.18, use 'ResampleOperation2D' instead.
#   from holoviews.operation.datashader import (
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# Starting WQ Simulation...
#  Assuming concentration input has units of mg/L...
#      If this is not true, please re-run the wq simulation with input_mass_units, input_volume_units, and liter_conversion parameters filled in appropriately.
#  25%
#  50%
#  75%
#  100%
#       Mass_start      Mass_end
# 0  770486.069402  1.222342e+06
#       Mass_start      Mass_end
# 0  770486.069402  1.545433e+06
# 1222341.733977332

# %%
plan11.plot(crs='EPSG:26916')
# Out:
# :DynamicMap   [datetime]
#    :Overlay
#       .Polygons.I :Polygons   [Longitude,Latitude]   (concentration)
#       .WMTS.I     :WMTS   [Longitude,Latitude]
