# %%
import xarray as xr

# %%
ds = xr.open_dataset(
    r'C:\Users\sjordan\OneDrive - LimnoTech\Documents\GitHub\ClearWater-riverine\examples\data_temp\sumwere_creek_coarse_p48\model_outputs.zarr',
    engine="zarr"
)

# %%
ds
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:            (nface: 444, time: 241)
# Coordinates:
#     face_x             (nface) float64 4kB ...
#     face_y             (nface) float64 4kB ...
#   * nface              (nface) int64 4kB 0 1 2 3 4 5 ... 438 439 440 441 442 443
#   * time               (time) datetime64[ns] 2kB 2022-05-13T08:00:00 ... 2022...
# Data variables:
#     tracer             (time, nface) float64 856kB ...
#     water_temperature  (time, nface) float64 856kB ...

# %%
ds.water_temperature.isel(nface=100).plot()

# %%
ds.water_temperature.isel(nface=100).values
# Out:
# array([10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
# ...

# %%
ds.close()
