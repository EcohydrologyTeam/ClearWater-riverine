# %% [markdown]
# # Issue 43: Integrate TSM into Clearwater Riverine

# %%
from clearwater_modules.tsm.model import EnergyBudget
import clearwater_modules.sorter as sorter
import numba

# %%
EnergyBudget.get_state_variables()
# Out:
# [Variable(name='water_temp_c', long_name='Water temperature', units='degC', description='TSM state variable for water temperature', use='state', process=CPUDispatcher(<function t_water_c at 0x00000292C1C74220>)),
#  Variable(name='surface_area', long_name='Surface area', units='m^2', description='Surface area', use='state', process=<function mock_equation at 0x00000292BDF02A20>),
#  Variable(name='volume', long_name='Volume', units='m^3', description='Volume', use='state', process=<function mock_equation at 0x00000292BDF02A20>)]

# %%
initial_state_values = {
    'water_temp_c': 1.0,
    'volume': 1.0,
    'surface_area': 1.0,
}

# %%
my_model = EnergyBudget(
    initial_state_values,
    time_dim='my_time_step',
)
my_model
# Out:
# Initializing from dicts...
# Model initialized from input dicts successfully!.

# %%
[i for i in dir(my_model) if i[0] != '_']
# Out:
# ['all_variables',
#  'computation_order',
#  'dataset',
#  'dynamic_variables',
#  'dynamic_variables_names',
#  'get_state_variables',
#  'get_variable',
#  'get_variable_names',
#  'hotstart_dataset',
#  'increment_timestep',
#  'initial_state_values',
#  'met_parameters',
#  'register_variable',
#  'state_variables',
#  'state_variables_names',
#  'static_variable_values',
#  'static_variables',
#  'static_variables_names',
#  'temp_parameters',
#  'time_dim',
#  'track_dynamic_variables',
#  'unregister_variables']

# %%
my_model.met_parameters
# Out:
# {'air_temp_c': 20,
#  'q_solar': 400,
#  'sed_temp_c': 5.0,
#  'eair_mb': 1.0,
#  'pressure_mb': 1013.0,
#  'cloudiness': 0.1,
#  'wind_speed': 3.0,
#  'wind_a': 0.3,
#  'wind_b': 1.5,
#  'wind_c': 1.0,
#  'wind_kh_kw': 1.0}

# %%
my_model.temp_parameters
# Out:
# {'stefan_boltzmann': 5.67e-08,
#  'cp_air': 1005,
#  'emissivity_water': 0.97,
#  'gravity': -9.806,
#  'a0': 6984.505294,
#  'a1': -188.903931,
#  'a2': 2.133357675,
#  'a3': -0.01288580973,
#  'a4': 4.393587233e-05,
#  'a5': -8.023923082e-08,
#  'a6': 6.136820929e-11,
#  'pb': 1600.0,
#  'cps': 1673.0,
#  'h2': 0.1,
#  'alphas': 0.0432,
#  'richardson_option': True}

# %%
my_model.time_dim
# Out:
# 'my_time_step'

# %%
display(my_model.static_variables)
# Out:
# [Variable(name='stefan_boltzmann', long_name='Stefan-Boltzmann Constant', units='W m-2 K-4', description='The Stefan-Boltzmann constant.', use='static', process=None),
#  Variable(name='cp_air', long_name='Specific Heat Capacity of Air', units='J kg-1 K-1', description='The specific heat capacity of air.', use='static', process=None),
#  Variable(name='emissivity_water', long_name='Emissivity of Water', units='1', description='The emissivity of water.', use='static', process=None),
#  Variable(name='gravity', long_name='Gravity', units='m s-2', description='The acceleration due to gravity.', use='static', process=None),
#  Variable(name='a0', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='a1', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='a2', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='a3', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='a4', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='a5', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='a6', long_name='Albedo of Water', units='unitless', description='The albedo of water.', use='static', process=None),
#  Variable(name='pb', long_name='Bulk Density of Sediment', units='kg m-3', description='The bulk density of sediment.', use='static', process=None),
#  Variable(name='cps', long_name='CPS', units='J kg-1 K-1', description='The CPS.', use='static', process=None),
#  Variable(name='h2', long_name='H2', units='m', description='The H2.', use='static', process=None),
#  Variable(name='alphas', long_name='Alphas', units='m-1', description='The alphas.', use='static', process=None),
#  Variable(name='richardson_option', long_name='Richardson Option', units='unitless', description='The Richardson option.', use='static', process=None),
#  Variable(name='air_temp_c', long_name='Air Temperature', units='C', description='The air temperature.', use='static', process=None),
#  Variable(name='q_solar', long_name='Solar Heat Flux', units='W m-2', description='The solar heat flux.', use='static', process=None),
#  Variable(name='sed_temp_c', long_name='Sediment Temperature', units='C', description='The sediment temperature.', use='static', process=None),
#  Variable(name='eair_mb', long_name='Eair MB', units='mb', description='The eair MB.', use='static', process=None),
#  Variable(name='pressure_mb', long_name='Pressure', units='mb', description='The pressure.', use='static', process=None),
#  Variable(name='cloudiness', long_name='Cloudiness', units='unitless', description='The cloudiness.', use='static', process=None),
#  Variable(name='wind_speed', long_name='Wind Speed', units='m s-1', description='The wind speed.', use='static', process=None),
#  Variable(name='wind_a', long_name='Wind A', units='m s-1', description='The wind A.', use='static', process=None),
#  Variable(name='wind_b', long_name='Wind B', units='m s-1', description='The wind B.', use='static', process=None),
#  Variable(name='wind_c', long_name='Wind C', units='m s-1', description='The wind C.', use='static', process=None),
#  Variable(name='wind_kh_kw', long_name='Wind KH KW', units='m s-1', description='The wind KH KW.', use='static', process=None)]

# %%
my_model.computation_order
# Out:
# [Variable(name='air_temp_k', long_name='Air temperature', units='K', description='Air temperature', use='dynamic', process=CPUDispatcher(<function air_temp_k at 0x00000292C1C60720>)),
#  Variable(name='water_temp_k', long_name='Water temperature', units='K', description='Water temperature', use='dynamic', process=CPUDispatcher(<function water_temp_k at 0x00000292C1C26700>)),
#  Variable(name='mixing_ratio_air', long_name='Mixing ratio of air', units='unitless', description='Mixing ratio of air', use='dynamic', process=CPUDispatcher(<function mixing_ratio_air at 0x00000292C1C607C0>)),
#  Variable(name='density_air', long_name='Density of air', units='kg/m^3', description='Density of air', use='dynamic', process=CPUDispatcher(<function density_air at 0x00000292C1C609A0>)),
#  Variable(name='density_water', long_name='Density of water', units='kg/m^3', description='Density of water', use='dynamic', process=CPUDispatcher(<function mf_density_water at 0x00000292C1C63420>)),
#  Variable(name='esat_mb', long_name='Saturation vapor pressure', units='mb', description='Saturation vapor pressure', use='dynamic', process=CPUDispatcher(<function mf_esat_mb at 0x00000292C1C62A20>)),
#  Variable(name='density_air_sat', long_name='Density of air at saturation', units='kg/m^3', description='Density of air at saturation', use='dynamic', process=CPUDispatcher(<function mf_density_air_sat at 0x00000292C1C63740>)),
#  Variable(name='ri_number', long_name='Richardson number', units='unitless', description='Richardson number', use='dynamic', process=CPUDispatcher(<function ri_number at 0x00000292C1C62CA0>)),
#  Variable(name='ri_function', long_name='Richardson function', units='unitless', description='Richardson function', use='dynamic', process=CPUDispatcher(<function ri_function at 0x00000292C1C62F20>)),
#  Variable(name='lv', long_name='Latent heat of vaporization', units='J/kg', description='Latent heat of vaporization', use='dynamic', process=CPUDispatcher(<function mf_latent_heat_vaporization at 0x00000292C1C631A0>)),
#  Variable(name='cp_water', long_name='Specific heat of water', units='J/kg/K', description='Specific heat of water', use='dynamic', process=CPUDispatcher(<function mf_cp_water at 0x00000292C1C639C0>)),
#  Variable(name='emissivity_air', long_name='Emissivity of air', units='unitless', description='Emissivity of air', use='dynamic', process=CPUDispatcher(<function emissivity_air at 0x00000292C1C60D60>)),
#  Variable(name='wind_function', long_name='Wind function', units='unitless', description='Wind function', use='dynamic', process=CPUDispatcher(<function wind_function at 0x00000292C1C60FE0>)),
#  Variable(name='q_latent', long_name='Latent heat flux', units='W/m^2', description='Latent heat flux', use='dynamic', process=CPUDispatcher(<function q_latent at 0x00000292C1C61260>)),
#  Variable(name='q_sensible', long_name='Sensible heat flux', units='W/m^2', description='Sensible heat flux', use='dynamic', process=CPUDispatcher(<function q_sensible at 0x00000292C1C614E0>)),
#  Variable(name='q_sediment', long_name='Sediment heat flux', units='W/m^2', description='Sediment heat flux', use='dynamic', process=CPUDispatcher(<function q_sediment at 0x00000292C1C61C60>)),
#  Variable(name='dTdt_sediment_c', long_name='Sediment temperature change', units='degC', description='Sediment temperature change', use='dynamic', process=CPUDispatcher(<function dTdt_sediment_c at 0x00000292C1C61E40>)),
#  Variable(name='q_longwave_down', long_name='Downwelling longwave radiation', units='W/m2', description='Downwelling longwave radiation', use='dynamic', process=CPUDispatcher(<function mf_q_longwave_down at 0x00000292C1C62480>)),
#  Variable(name='q_longwave_up', long_name='Upwelling longwave radiation', units='W/m2', description='Upwelling longwave radiation', use='dynamic', process=CPUDispatcher(<function mf_q_longwave_up at 0x00000292C1C62700>)),
#  Variable(name='surface_area', long_name='Surface area', units='m^2', description='Surface area', use='state', process=<function mock_equation at 0x00000292BDF02A20>),
#  Variable(name='volume', long_name='Volume', units='m^3', description='Volume', use='state', process=<function mock_equation at 0x00000292BDF02A20>),
#  Variable(name='q_net', long_name='Net heat flux', units='W/m^2', description='Net heat flux', use='dynamic', process=CPUDispatcher(<function q_net at 0x00000292C1C63CE0>)),
#  Variable(name='dTdt_water_c', long_name='Water temperature change', units='degC', description='Water temperature change', use='dynamic', process=CPUDispatcher(<function dTdt_water_c at 0x00000292C1C740E0>)),
#  Variable(name='water_temp_c', long_name='Water temperature', units='degC', description='TSM state variable for water temperature', use='state', process=CPUDispatcher(<function t_water_c at 0x00000292C1C74220>))]

# %%
for i in my_model.computation_order:
    print(f'{i.name} | {sorter.get_process_args(i.process)}')
# Out:
# air_temp_k | ['air_temp_c']
# water_temp_k | ['water_temp_c']
# mixing_ratio_air | ['eair_mb', 'pressure_mb']
# density_air | ['pressure_mb', 'air_temp_k', 'mixing_ratio_air']
# density_water | ['water_temp_c']
# esat_mb | ['water_temp_k', 'a0', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6']
# density_air_sat | ['water_temp_k', 'esat_mb', 'pressure_mb']
# ri_number | ['gravity', 'density_air', 'density_air_sat', 'wind_speed']
# ri_function | ['ri_number']
# lv | ['water_temp_k']
# cp_water | ['water_temp_c']
# emissivity_air | ['air_temp_k']
# wind_function | ['wind_a', 'wind_b', 'wind_c', 'wind_speed']
# q_latent | ['ri_function', 'pressure_mb', 'density_water', 'lv', 'wind_function', 'esat_mb', 'eair_mb']
# q_sensible | ['wind_kh_kw', 'ri_function', 'cp_air', 'density_water', 'wind_function', 'air_temp_k', 'water_temp_k']
# q_sediment | ['pb', 'cps', 'alphas', 'h2', 'sed_temp_c', 'water_temp_c']
# dTdt_sediment_c | ['alphas', 'h2', 'water_temp_c', 'sed_temp_c']
# q_longwave_down | ['air_temp_k', 'emissivity_air', 'cloudiness', 'stefan_boltzmann']
# q_longwave_up | ['water_temp_k', 'emissivity_water', 'stefan_boltzmann']
# surface_area | ['water_temp_c']
# volume | ['water_temp_c']
# q_net | ['q_sensible', 'q_latent', 'q_longwave_up', 'q_longwave_down', 'q_solar', 'q_sediment']
# dTdt_water_c | ['q_net', 'surface_area', 'volume', 'density_water', 'cp_water']
# water_temp_c | ['water_temp_c', 'dTdt_water_c']

# %%
TIME_STEPS = 1

# %%
@numba.jit(forceobj=True)
def run_n_timesteps(time_steps: int, model: EnergyBudget):
    for i in range(time_steps):
        model.increment_timestep()

# %%
# %%time
run_n_timesteps(TIME_STEPS, my_model)
# Out:
# CPU times: total: 4.72 s
# Wall time: 5.32 s

# %%
my_model.dataset
# Out:
# <xarray.Dataset>
# Dimensions:            (my_time_step: 2, x: 1, y: 1)
# Coordinates:
#   * my_time_step       (my_time_step) int32 0 1
#   * x                  (x) float64 1.0
#   * y                  (y) float64 1.0
# Data variables: (12/51)
#     water_temp_c       (my_time_step, x, y) float64 1.0 0.9299
#     volume             (my_time_step, x, y) float64 1.0 1.0
#     surface_area       (my_time_step, x, y) float64 1.0 1.0
#     stefan_boltzmann   (x, y) float64 5.67e-08
#     cp_air             (x, y) int32 1005
#     emissivity_water   (x, y) float64 0.97
#     ...                 ...
#     q_sediment         (my_time_step, x, y) float64 nan 107.1
#     dTdt_sediment_c    (my_time_step, x, y) float64 nan -34.56
#     q_longwave_down    (my_time_step, x, y) float64 nan 337.8
#     q_longwave_up      (my_time_step, x, y) float64 nan 310.7
#     q_net              (my_time_step, x, y) float64 nan -140.2
#     dTdt_water_c       (my_time_step, x, y) float64 nan -0.07009
